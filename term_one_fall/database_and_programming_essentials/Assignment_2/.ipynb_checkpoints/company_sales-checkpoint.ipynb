# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import os

# 1a. Read data from the sales.csv file into pandas dataframes.
sales_df = pd.read_csv('sales.csv')

# 1a. Read data from the sales_team.csv file into pandas dataframes.
sales_team_df = pd.read_csv('sales_teams.csv')

# Combine the two dataframes based on Sales Agent column
combined_df = pd.merge(sales_df, sales_team_df, on='Sales Agent', how='left')
combined_df['Product Name'].unique()
# Out:
# array(['GTX Plus Basic', 'GTXPro', 'MG Special', 'GTX Basic',
#        'MG Advanced', 'GTX Plus Pro', 'GTK 500'], dtype=object)

# %%
combined_df['Regional Office'].unique()
# Out:
# array(['Central', 'West', 'East'], dtype=object)

# %%
# 2a. Rename the columns in both datasets, making all lowercase and replacing space with an underscore.
combined_df.columns = combined_df.columns.str.lower().str.replace(' ', '_')
combined_df.head(10)
# Out:
#    sales_id      sales_agent    product_name        account deal_stage  \
# 0  1C1I7A6R      Moses Frase  GTX Plus Basic        Cancity        Won
# 1  Z063OYW0  Darcel Schlecht          GTXPro          Isdom        Won
# 2  EC4QE1BX  Darcel Schlecht      MG Special        Cancity        Won
# 3  MV1LWRNH      Moses Frase       GTX Basic        Codehow        Won
# 4  PE84CX4O        Zane Levy       GTX Basic         Hatfan        Won
# 5  ZNBS69V1    Anna Snelling      MG Special       Ron-tech        Won
# 6  9ME3374G   Vicki Laflamme      MG Special        J-Texon        Won
# 7  7GN8Q4LL   Markita Hansen       GTX Basic         Cheers        Won
# 8  OLK9LKZB  Niesha Huffines  GTX Plus Basic       Zumgoity        Won
# 9  HAXMC4IX   James Ascencio     MG Advanced  Not Available   Engaging
#
#   deal_engage_date deal_close_date close_value_per_unit closing_quantity  \
# 0       2016-10-20      2017-03-01                 1054               22
# 1       2016-10-25      2017-03-11                 4514               50
# 2       2016-10-25      2017-03-07                   50               18
# 3       2016-10-25      2017-03-09                  588               44
# 4       2016-10-25      2017-03-02                  517               25
# 5       2016-10-29      2017-03-01                   49               20
# 6       2016-10-30      2017-03-02                   57               37
# 7       2016-11-01      2017-03-07                  601               26
# 8       2016-11-01      2017-03-03                 1026               22
# 9       2016-11-03   Not Available        Not Available          Unknown
#
#             manager regional_office
# 0  Dustin Brinkmann         Central
# 1     Melvin Marxen         Central
# 2     Melvin Marxen         Central
# 3  Dustin Brinkmann         Central
# 4     Summer Sewald            West
# 5  Dustin Brinkmann         Central
# 6      Celia Rouche            West
# 7      Celia Rouche            West
# 8     Melvin Marxen         Central
# 9     Summer Sewald            West

# %%
# 2b. Identify the missing values with ‘Not Available’ and ‘Unknown’, and then replace them with NaN values.
combined_df.replace(['Not Available', 'Unknown'], np.nan, inplace=True)
combined_df.head(10)
# Out:
#    sales_id      sales_agent    product_name   account deal_stage  \
# 0  1C1I7A6R      Moses Frase  GTX Plus Basic   Cancity        Won
# 1  Z063OYW0  Darcel Schlecht          GTXPro     Isdom        Won
# 2  EC4QE1BX  Darcel Schlecht      MG Special   Cancity        Won
# 3  MV1LWRNH      Moses Frase       GTX Basic   Codehow        Won
# 4  PE84CX4O        Zane Levy       GTX Basic    Hatfan        Won
# 5  ZNBS69V1    Anna Snelling      MG Special  Ron-tech        Won
# 6  9ME3374G   Vicki Laflamme      MG Special   J-Texon        Won
# 7  7GN8Q4LL   Markita Hansen       GTX Basic    Cheers        Won
# 8  OLK9LKZB  Niesha Huffines  GTX Plus Basic  Zumgoity        Won
# 9  HAXMC4IX   James Ascencio     MG Advanced       NaN   Engaging
#
#   deal_engage_date deal_close_date close_value_per_unit closing_quantity  \
# 0       2016-10-20      2017-03-01                 1054               22
# 1       2016-10-25      2017-03-11                 4514               50
# 2       2016-10-25      2017-03-07                   50               18
# 3       2016-10-25      2017-03-09                  588               44
# 4       2016-10-25      2017-03-02                  517               25
# 5       2016-10-29      2017-03-01                   49               20
# 6       2016-10-30      2017-03-02                   57               37
# 7       2016-11-01      2017-03-07                  601               26
# 8       2016-11-01      2017-03-03                 1026               22
# 9       2016-11-03             NaN                  NaN              NaN
#
#             manager regional_office
# 0  Dustin Brinkmann         Central
# 1     Melvin Marxen         Central
# 2     Melvin Marxen         Central
# 3  Dustin Brinkmann         Central
# 4     Summer Sewald            West
# 5  Dustin Brinkmann         Central
# 6      Celia Rouche            West
# 7      Celia Rouche            West
# 8     Melvin Marxen         Central
# 9     Summer Sewald            West

# %%
# 3a. Add a new column, to determine the ‘Total Sales Value’ using the deal closing values and quantities.
combined_df['close_value_per_unit'] = pd.to_numeric(combined_df['close_value_per_unit'], errors='coerce')
combined_df['closing_quantity'] = pd.to_numeric(combined_df['closing_quantity'], errors='coerce')

combined_df['total_sales_value'] = combined_df['close_value_per_unit'] * combined_df['closing_quantity']
combined_df.head(10)
# Out:
#    sales_id      sales_agent    product_name   account deal_stage  \
# 0  1C1I7A6R      Moses Frase  GTX Plus Basic   Cancity        Won
# 1  Z063OYW0  Darcel Schlecht          GTXPro     Isdom        Won
# 2  EC4QE1BX  Darcel Schlecht      MG Special   Cancity        Won
# 3  MV1LWRNH      Moses Frase       GTX Basic   Codehow        Won
# 4  PE84CX4O        Zane Levy       GTX Basic    Hatfan        Won
# 5  ZNBS69V1    Anna Snelling      MG Special  Ron-tech        Won
# 6  9ME3374G   Vicki Laflamme      MG Special   J-Texon        Won
# 7  7GN8Q4LL   Markita Hansen       GTX Basic    Cheers        Won
# 8  OLK9LKZB  Niesha Huffines  GTX Plus Basic  Zumgoity        Won
# 9  HAXMC4IX   James Ascencio     MG Advanced       NaN   Engaging
#
#   deal_engage_date deal_close_date  close_value_per_unit  closing_quantity  \
# 0       2016-10-20      2017-03-01                1054.0              22.0
# 1       2016-10-25      2017-03-11                4514.0              50.0
# 2       2016-10-25      2017-03-07                  50.0              18.0
# 3       2016-10-25      2017-03-09                 588.0              44.0
# 4       2016-10-25      2017-03-02                 517.0              25.0
# 5       2016-10-29      2017-03-01                  49.0              20.0
# 6       2016-10-30      2017-03-02                  57.0              37.0
# 7       2016-11-01      2017-03-07                 601.0              26.0
# 8       2016-11-01      2017-03-03                1026.0              22.0
# 9       2016-11-03             NaN                   NaN               NaN
#
#             manager regional_office  total_sales_value
# 0  Dustin Brinkmann         Central            23188.0
# 1     Melvin Marxen         Central           225700.0
# 2     Melvin Marxen         Central              900.0
# 3  Dustin Brinkmann         Central            25872.0
# 4     Summer Sewald            West            12925.0
# 5  Dustin Brinkmann         Central              980.0
# 6      Celia Rouche            West             2109.0
# 7      Celia Rouche            West            15626.0
# 8     Melvin Marxen         Central            22572.0
# 9     Summer Sewald            West                NaN

# %%
# 3b. Add a new column, to list the ‘Sales Region’ based on sales agent’s regional office information available in the sales team dataset.
combined_df.rename(columns={'regional_office': 'sales_region'}, inplace=True)
combined_df.head(10)
# Out:
#    sales_id      sales_agent    product_name   account deal_stage  \
# 0  1C1I7A6R      Moses Frase  GTX Plus Basic   Cancity        Won
# 1  Z063OYW0  Darcel Schlecht          GTXPro     Isdom        Won
# 2  EC4QE1BX  Darcel Schlecht      MG Special   Cancity        Won
# 3  MV1LWRNH      Moses Frase       GTX Basic   Codehow        Won
# 4  PE84CX4O        Zane Levy       GTX Basic    Hatfan        Won
# 5  ZNBS69V1    Anna Snelling      MG Special  Ron-tech        Won
# 6  9ME3374G   Vicki Laflamme      MG Special   J-Texon        Won
# 7  7GN8Q4LL   Markita Hansen       GTX Basic    Cheers        Won
# 8  OLK9LKZB  Niesha Huffines  GTX Plus Basic  Zumgoity        Won
# 9  HAXMC4IX   James Ascencio     MG Advanced       NaN   Engaging
#
#   deal_engage_date deal_close_date  close_value_per_unit  closing_quantity  \
# 0       2016-10-20      2017-03-01                1054.0              22.0
# 1       2016-10-25      2017-03-11                4514.0              50.0
# 2       2016-10-25      2017-03-07                  50.0              18.0
# 3       2016-10-25      2017-03-09                 588.0              44.0
# 4       2016-10-25      2017-03-02                 517.0              25.0
# 5       2016-10-29      2017-03-01                  49.0              20.0
# 6       2016-10-30      2017-03-02                  57.0              37.0
# 7       2016-11-01      2017-03-07                 601.0              26.0
# 8       2016-11-01      2017-03-03                1026.0              22.0
# 9       2016-11-03             NaN                   NaN               NaN
#
#             manager sales_region  total_sales_value
# 0  Dustin Brinkmann      Central            23188.0
# 1     Melvin Marxen      Central           225700.0
# 2     Melvin Marxen      Central              900.0
# 3  Dustin Brinkmann      Central            25872.0
# 4     Summer Sewald         West            12925.0
# 5  Dustin Brinkmann      Central              980.0
# 6      Celia Rouche         West             2109.0
# 7      Celia Rouche         West            15626.0
# 8     Melvin Marxen      Central            22572.0
# 9     Summer Sewald         West                NaN

# %%
# 4. Convert 'deal_engage_date' and 'deal_close_date' from object data type to datetime
combined_df['deal_engage_date'] = pd.to_datetime(combined_df['deal_engage_date'], format="%Y-%m-%d", errors='coerce')
combined_df['deal_close_date'] = pd.to_datetime(combined_df['deal_close_date'], format="%Y-%m-%d", errors='coerce')

combined_df.head(10)
# Out:
#    sales_id      sales_agent    product_name   account deal_stage  \
# 0  1C1I7A6R      Moses Frase  GTX Plus Basic   Cancity        Won
# 1  Z063OYW0  Darcel Schlecht          GTXPro     Isdom        Won
# 2  EC4QE1BX  Darcel Schlecht      MG Special   Cancity        Won
# 3  MV1LWRNH      Moses Frase       GTX Basic   Codehow        Won
# 4  PE84CX4O        Zane Levy       GTX Basic    Hatfan        Won
# 5  ZNBS69V1    Anna Snelling      MG Special  Ron-tech        Won
# 6  9ME3374G   Vicki Laflamme      MG Special   J-Texon        Won
# 7  7GN8Q4LL   Markita Hansen       GTX Basic    Cheers        Won
# 8  OLK9LKZB  Niesha Huffines  GTX Plus Basic  Zumgoity        Won
# 9  HAXMC4IX   James Ascencio     MG Advanced       NaN   Engaging
#
#   deal_engage_date deal_close_date  close_value_per_unit  closing_quantity  \
# 0       2016-10-20      2017-03-01                1054.0              22.0
# 1       2016-10-25      2017-03-11                4514.0              50.0
# 2       2016-10-25      2017-03-07                  50.0              18.0
# 3       2016-10-25      2017-03-09                 588.0              44.0
# 4       2016-10-25      2017-03-02                 517.0              25.0
# 5       2016-10-29      2017-03-01                  49.0              20.0
# 6       2016-10-30      2017-03-02                  57.0              37.0
# 7       2016-11-01      2017-03-07                 601.0              26.0
# 8       2016-11-01      2017-03-03                1026.0              22.0
# 9       2016-11-03             NaT                   NaN               NaN
#
#             manager sales_region  total_sales_value
# 0  Dustin Brinkmann      Central            23188.0
# 1     Melvin Marxen      Central           225700.0
# 2     Melvin Marxen      Central              900.0
# 3  Dustin Brinkmann      Central            25872.0
# 4     Summer Sewald         West            12925.0
# 5  Dustin Brinkmann      Central              980.0
# 6      Celia Rouche         West             2109.0
# 7      Celia Rouche         West            15626.0
# 8     Melvin Marxen      Central            22572.0
# 9     Summer Sewald         West                NaN

# %%
# 5. Drop 'close_value_per_unit' and 'closing_quantity' columns, and other redundant columns
columns_to_drop = ['close_value_per_unit', 'closing_quantity']
combined_df.drop(columns=columns_to_drop, inplace=True)
combined_df.head(10)
# Out:
#    sales_id      sales_agent    product_name   account deal_stage  \
# 0  1C1I7A6R      Moses Frase  GTX Plus Basic   Cancity        Won
# 1  Z063OYW0  Darcel Schlecht          GTXPro     Isdom        Won
# 2  EC4QE1BX  Darcel Schlecht      MG Special   Cancity        Won
# 3  MV1LWRNH      Moses Frase       GTX Basic   Codehow        Won
# 4  PE84CX4O        Zane Levy       GTX Basic    Hatfan        Won
# 5  ZNBS69V1    Anna Snelling      MG Special  Ron-tech        Won
# 6  9ME3374G   Vicki Laflamme      MG Special   J-Texon        Won
# 7  7GN8Q4LL   Markita Hansen       GTX Basic    Cheers        Won
# 8  OLK9LKZB  Niesha Huffines  GTX Plus Basic  Zumgoity        Won
# 9  HAXMC4IX   James Ascencio     MG Advanced       NaN   Engaging
#
#   deal_engage_date deal_close_date           manager sales_region  \
# 0       2016-10-20      2017-03-01  Dustin Brinkmann      Central
# 1       2016-10-25      2017-03-11     Melvin Marxen      Central
# 2       2016-10-25      2017-03-07     Melvin Marxen      Central
# 3       2016-10-25      2017-03-09  Dustin Brinkmann      Central
# 4       2016-10-25      2017-03-02     Summer Sewald         West
# 5       2016-10-29      2017-03-01  Dustin Brinkmann      Central
# 6       2016-10-30      2017-03-02      Celia Rouche         West
# 7       2016-11-01      2017-03-07      Celia Rouche         West
# 8       2016-11-01      2017-03-03     Melvin Marxen      Central
# 9       2016-11-03             NaT     Summer Sewald         West
#
#    total_sales_value
# 0            23188.0
# 1           225700.0
# 2              900.0
# 3            25872.0
# 4            12925.0
# 5              980.0
# 6             2109.0
# 7            15626.0
# 8            22572.0
# 9                NaN

# %%
# 6. Create a new database named ‘CRM’ and write the dataset into a table named ‘sales’
os.environ['MYSQL_PASSWORD'] = "12345678"
password = os.getenv('MYSQL_PASSWORD')

# Create engine and handle connection errors
engine = create_engine(f'mysql+mysqlconnector://root:{password}@localhost/CRM',
            connect_args={'auth_plugin': 'caching_sha2_password'})
print(f"Mysql is connected successfully with create_engine: {engine}")

combined_df.to_sql('sales', con=engine, if_exists='replace', index=False)
# Out:
# Mysql is connected successfully with create_engine: Engine(mysql+mysqlconnector://root:***@localhost/CRM)
# 8800

# %%
# 7a.Find top 5 sales agents along with their sales revenue.
query_a = """
    SELECT sales_agent, SUM(total_sales_value) AS sales_revenue
    FROM sales
    GROUP BY sales_agent
    ORDER BY sales_revenue DESC
    LIMIT 5;
"""

top_sales_agents = pd.read_sql(query_a, engine)
top_sales_agents.head(10)
# Out:
#        sales_agent  sales_revenue
# 0  Darcel Schlecht     34399968.0
# 1   Vicki Laflamme     14742098.0
# 2    Donn Cantrell     14371400.0
# 3     Cassey Cress     14125702.0
# 4  Kary Hendrixson     13939628.0

# %%
# 7b. Find the total value of sales closed by different regions.
query_b = """
    SELECT sales_region, SUM(total_sales_value) AS total_sales_value
    FROM sales
    GROUP BY sales_region
    ORDER BY total_sales_value DESC;
"""

total_sales_by_region = pd.read_sql(query_b, engine)
total_sales_by_region.head(10)
# Out:
#   sales_region  total_sales_value
# 0         West        104298708.0
# 1      Central        101367188.0
# 2         East         95171391.0

# %%
# Find the list of returning customers in descending order of their respective ‘repeat customer rate’
# (i.e., the percentage of closed deals from returning customers).
# Please note that the 'account' column in the 'sales' contains the information about their business clients which you may refer to as the 'customers'

query_c = """
    WITH closed_deals AS (
        SELECT 
            account, 
            COUNT(*) AS total_deals,
            SUM(CASE WHEN TRIM(LOWER(deal_stage)) = 'won' THEN 1 ELSE 0 END) AS closed_deals
        FROM sales
        GROUP BY account
        HAVING COUNT(*) > 1
    )
    SELECT 
        account,
        closed_deals,
        total_deals,
        (closed_deals * 100.0 / total_deals) AS repeat_customer_rate
    FROM closed_deals
    ORDER BY repeat_customer_rate DESC;

"""

returning_customers = pd.read_sql(query_c, engine)
returning_customers.head(10)
# Out:
#         account  closed_deals  repeat_customer_rate
# 0      Rangreen          75.0              68.80734
# 1    Goodsilron          65.0              68.42105
# 2    Gekko & Co          60.0              68.18182
# 3         Newex          37.0              67.27273
# 4     Warephase          70.0              66.03774
# 5    Stanredtax          69.0              65.09434
# 6       J-Texon          50.0              64.93506
# 7      Gogozoom          51.0              64.55696
# 8  Singletechno          72.0              64.28571
# 9        Finjob          57.0              64.04494

# %%
combined_df['deal_stage'].unique()
# Out:
# array(['Won', 'Engaging', 'Lost', 'Prospecting'], dtype=object)
