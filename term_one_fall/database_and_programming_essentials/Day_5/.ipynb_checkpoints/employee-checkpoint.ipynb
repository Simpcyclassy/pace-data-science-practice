# %%
import xml.etree.ElementTree as ET
import mysql.connector as sql
# Parse XML file
tree = ET.parse('employee_2.xml’)
root = tree.getroot()
# Connect to MySQL
mydb = sql.connect(host = "localhost", user =
"root",password="mypass",use_pure="true")
mycursor = mydb.cursor()
mycursor.execute("use day5;")
