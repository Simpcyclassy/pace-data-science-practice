# %%
import pandas as pd
from ydata_profiling import ProfileReport

df = pd.read_csv('MichelleObama_tweets.csv')
profile = ProfileReport(df, title="Profiling Report")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[25], line 2
#       1 import pandas as pd
# ----> 2 from ydata_profiling import ProfileReport
#       4 df = pd.read_csv('MichelleObama_tweets.csv')
#       5 profile = ProfileReport(df, title="Profiling Report")
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/ydata_profiling/__init__.py:8
#       6 # ignore numba warnings
#       7 import warnings  # isort:skip # noqa
# ----> 8 from numba.core.errors import NumbaDeprecationWarning  # isort:skip # noqa
#      10 warnings.simplefilter("ignore", category=NumbaDeprecationWarning)
#      12 import importlib.util  # isort:skip # noqa
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/numba/__init__.py:59
#      54             msg = ("Numba requires SciPy version 1.0 or greater. Got SciPy "
#      55                    f"{scipy.__version__}.")
# ...

# %%
import sweetviz as sv
import pandas as pd
URL = 'https://data.cityofnewyork.us/api/views/e5c5-ieuv/rows.csv'
df_csv = pd.read_csv('MichelleObama_tweets.csv')
df_csv.head()
my_report = sv.analyze(df_csv)
my_report.show_html()
# Out:
# Feature: id                                  |██████▌                                       | [ 14%]   00:00 -> (00:00 left)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 6
#       4 df_csv = pd.read_csv('MichelleObama_tweets.csv')
#       5 df_csv.head()
# ----> 6 my_report = sv.analyze(df_csv)
#       7 my_report.show_html()
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/sweetviz/sv_public.py:12, in analyze(source, target_feat, feat_cfg, pairwise_analysis)
#       8 def analyze(source: Union[pd.DataFrame, Tuple[pd.DataFrame, str]],
#       9             target_feat: str = None,
#      10             feat_cfg: FeatureConfig = None,
#      11             pairwise_analysis: str = 'auto'):
# ---> 12     report = sweetviz.DataframeReport(source, target_feat, None,
#      13                                       pairwise_analysis, feat_cfg)
# ...
