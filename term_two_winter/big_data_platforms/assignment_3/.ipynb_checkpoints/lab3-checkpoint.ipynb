# %% [markdown]
# # **Exploring a Public Dataset with Dataprep on Google Cloud Platform**
#
# ## **Introduction**
#
# In this assignment, I am exploring the **Chicago Crime dataset** using **Google Cloud Dataprep**, a powerful data preparation tool that allows me to clean, transform, and analyze data through an intuitive visual interface. The dataset includes detailed records of reported crimes in Chicago from 2001 to the present, capturing key information such as date, location, crime type, arrest status, and more.
#
# I am using Dataprep to understand the structure of the dataset, handle missing or inconsistent values, and apply transformations that improve data quality. Through built-in profiling tools and visualizations, I gain insights into crime trends across time, geography, and category.
#
# ---
#
# ## **Objectives**
#
# - To import and explore the **Chicago Crime dataset** within Google Cloud Dataprep.
# - To perform **data cleaning and transformation** tasks such as removing duplicates, handling null values, and formatting fields.
# - To use **profiling and visualization features** to detect trends and outliers in the data.
# - To write **SQL-like queries** in Dataprep for analyzing crime frequency, types, and distribution.
# - To document my workflow and highlight key observations for reporting and presentation.

# %%
import pandas as pd

# Load both CSVs
chicago_crime = pd.read_csv("chicago_crime.csv")
extended = pd.read_csv("extended.csv")

# Merge (stack vertically)
merged = pd.concat([chicago_crime, extended], ignore_index=True)

# Preview the result
merged.head()
# Out:
#    Year  Hour       Day   Month                  Block           Crime_Type  \
# 0  2023    13    Monday    July  080XX S INGLESIDE AVE    CRIMINAL TRESPASS
# 1  2023    23  Thursday    June   048XX W FERDINAND ST    WEAPONS VIOLATION
# 2  2023    21    Friday    July   029XX N CLYBOURN AVE              ASSAULT
# 3  2023     1    Monday  August  019XX S FAIRFIELD AVE    WEAPONS VIOLATION
# 4  2023     7    Sunday    June        039XX W POLK ST  MOTOR VEHICLE THEFT
#
#                      Description Location_Description  Arrest  Domestic  \
# 0                   TO RESIDENCE            APARTMENT   False     False
# 1  UNLAWFUL POSSESSION - HANDGUN             SIDEWALK    True     False
# 2                         SIMPLE            APARTMENT   False      True
# 3  UNLAWFUL POSSESSION - HANDGUN               STREET    True     False
# 4                     AUTOMOBILE               STREET   False     False
#
#     District      Community_Area   Latitude  Longitude
# 0    Gresham             Chatham  41.748739 -87.601474
# 1     Austin              Austin  41.889557 -87.746884
# 2  Town Hall        North Center  41.934844 -87.681675
# 3      Ogden      South Lawndale  41.854152 -87.694285
# 4   Harrison  West Garfield Park  41.870740 -87.723749

# %%
df_map = merged[['Latitude', 'Longitude', 'Crime_Type']].dropna().head(500)

# %%
import folium

# Center the map on Chicago
map_center = [41.8781, -87.6298]  # Chicago's coordinates
crime_map = folium.Map(location=map_center, zoom_start=11)

# Add points
for _, row in df_map.iterrows():
    folium.CircleMarker(
        location=[row['Latitude'], row['Longitude']],
        radius=3,
        popup=row['Crime_Type'],
        fill=True,
        color='red',
        fill_opacity=0.6
    ).add_to(crime_map)

# Display it
crime_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d923a04bb5fa6bdef661002e25b88959 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d923a04bb5fa6bdef661002e25b88959&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d923a04bb5fa6bdef661002e25b88959 = L.map(
#                 &quot;map_d923a04bb5fa6bdef661002e25b88959&quot;,
#                 {
#                     center: [41.8781, -87.6298],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_199a62610b821427f3e140504e0bae88 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_199a62610b821427f3e140504e0bae88.addTo(map_d923a04bb5fa6bdef661002e25b88959);
#
#
#             var circle_marker_329a5ab5010c03eb8b1159541111df69 = L.circleMarker(
#                 [41.748739429, -87.601473872],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d923a04bb5fa6bdef661002e25b88959);
#
#
#         var popup_0c42532ac41e4841060f5b3f8e325d66 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fcfd222a7a97622fd3b7262a1e6c88dd = $(`&lt;div id=&quot;html_fcfd222a7a97622fd3b7262a1e6c88dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CRIMINAL TRESPASS&lt;/div&gt;`)[0];
#                 popup_0c42532ac41e4841060f5b3f8e325d66.setContent(html_fcfd222a7a97622fd3b7262a1e6c88dd);
#
#
#
#         circle_marker_329a5ab5010c03eb8b1159541111df69.bindPopup(popup_0c42532ac41e4841060f5b3f8e325d66)
#         ;
#
#
#
#
#             var circle_marker_ddff1dbe47b0bf7994633839c4c49c79 = L.circleMarker(
#                 [41.889556544, -87.746884193],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d923a04bb5fa6bdef661002e25b88959);
#
#
#         var popup_37dd4902e5a0a75efeefc88031780189 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf5d7e4e8df82a6131eee0b403beddd2 = $(`&lt;div id=&quot;html_cf5d7e4e8df82a6131eee0b403beddd2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WEAPONS VIOLATION&lt;/div&gt;`)[0];
#                 popup_37dd4902e5a0a75efeefc88031780189.setContent(html_cf5d7e4e8df82a6131eee0b403beddd2);
#
#
#
#         circle_marker_ddff1dbe47b0bf7994633839c4c49c79.bindPopup(popup_37dd4902e5a0a75efeefc88031780189)
#         ;
#
#
#
#
#             var circle_marker_dd717dd9b7823f0bfa7d48f7e24ba939 = L.circleMarker(
#                 [41.934844327, -87.681675129],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d923a04bb5fa6bdef661002e25b88959);
#
#
#         var popup_f1fccf06a084db844ae13fb000ef920c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_73cd7fc6dad6b8f495094278b205307b = $(`&lt;div id=&quot;html_73cd7fc6dad6b8f495094278b205307b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ASSAULT&lt;/div&gt;`)[0];
#                 popup_f1fccf06a084db844ae13fb000ef920c.setContent(html_73cd7fc6dad6b8f495094278b205307b);
#
#
#
#         circle_marker_dd717dd9b7823f0bfa7d48f7e24ba939.bindPopup(popup_f1fccf06a084db844ae13fb000ef920c)
#         ;
#
#
#
#
#             var circle_marker_58c1a541e1bf4877445c9d65b2f169df = L.circleMarker(
#                 [41.854152217, -87.694284875],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: t
